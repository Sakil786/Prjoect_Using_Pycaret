# %%
#reading dataset
import pandas as pd
data=pd.read_csv('pokemon.csv')

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#converting boolean column Legendary to integer
data["Legendary"] = data["Legendary"].view('i1')

# %%
#saving the data
data.to_csv('pokemon_integer.csv')

# %%
#import classification module
from pycaret.classification import *
#intialize the setup
exp_clf = setup(data, target = 'Legendary')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_6dfaf5a4_8c9d_11ea_b798_c8f733042b03row4_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_6dfaf5a4_8c9d_11ea_b798_c8f733042b03" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6dfaf5a4_8c9d_11ea_b798_c8f733042b03level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6dfaf5a4_8c9d_11ea_b798_c8f733042b03row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_6dfaf5a4_8c9d_11ea_b798_c8f733042b03row0_col1" class="data row0 col1" >4799</td>
#             </tr>
#             <tr>
#                         <th id="T_6dfaf5a4_8c9d_11ea_b798_c8f733042b03level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_cf51d642_8c9d_11ea_b798_c8f733042b03 th {
#           text-align: left;
#     }    #T_cf51d642_8c9d_11ea_b798_c8f733042b03row0_col0 {
#             text-align:  left;
#         }    #T_cf51d642_8c9d_11ea_b798_c8f733042b03row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_cf51d642_8c9d_11ea_b798_c8f733042b03row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_cf51d642_8c9d_11ea_b798_c8f733042b03row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_cf51d642_8c9d_11ea_b798_c8f733042b03row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_cf51d642_8c9d_11ea_b798_c8f733042b03row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_cf51d642_8c9d_11ea_b798_c8f733042b03row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...

# %%
lr = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9643  1.0000    1.00  0.7143  0.8333  0.8140
# 1       0.9821  1.0000    1.00  0.8333  0.9091  0.8993
# 2       0.9643  0.9922    0.60  1.0000  0.7500  0.7321
# 3       0.9821  1.0000    1.00  0.8333  0.9091  0.8993
# 4       1.0000  1.0000    1.00  1.0000  1.0000  1.0000
# 5       0.9821  0.9961    1.00  0.8333  0.9091  0.8993
# 6       1.0000  1.0000    1.00  1.0000  1.0000  1.0000
# 7       1.0000  1.0000    1.00  1.0000  1.0000  1.0000
# 8       1.0000  1.0000    1.00  1.0000  1.0000  1.0000
# 9       0.9818  1.0000    1.00  0.8333  0.9091  0.8991
# Mean    0.9857  0.9988    0.96  0.9048  0.9220  0.9143
# SD      0.0134  0.0025    0.12  0.1010  0.0790  0.0858

# %%
#create a model
lr = create_model('lightgbm')
#plot a model
plot_model(lr)

# %%
#create a model
lr = create_model('lightgbm')
#evaluate a model
evaluate_model(lr)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9643  1.0000    1.00  0.7143  0.8333  0.8140
# 1       0.9821  1.0000    1.00  0.8333  0.9091  0.8993
# 2       0.9643  0.9922    0.60  1.0000  0.7500  0.7321
# 3       0.9821  1.0000    1.00  0.8333  0.9091  0.8993
# 4       1.0000  1.0000    1.00  1.0000  1.0000  1.0000
# 5       0.9821  0.9961    1.00  0.8333  0.9091  0.8993
# 6       1.0000  1.0000    1.00  1.0000  1.0000  1.0000
# 7       1.0000  1.0000    1.00  1.0000  1.0000  1.0000
# 8       1.0000  1.0000    1.00  1.0000  1.0000  1.0000
# 9       0.9818  1.0000    1.00  0.8333  0.9091  0.8991
# Mean    0.9857  0.9988    0.96  0.9048  0.9220  0.9143
# SD      0.0134  0.0025    0.12  0.1010  0.0790  0.0858
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
